# %% [markdown]
# # Anomaly Detection Using Gaussian Distribution
#
# _Source: 🤖[Homemade Machine Learning](https://github.com/trekhleb/homemade-machine-learning) repository_
#
# > ☝Before moving on with this demo you might want to take a look at:
# > - 📗[Math behind the Anomaly Detection](https://github.com/trekhleb/homemade-machine-learning/tree/master/homemade/anomaly_detection)
# > - ⚙️[Gaussian Anomaly Detection Source Code](https://github.com/trekhleb/homemade-machine-learning/blob/master/homemade/anomaly_detection/gaussian_anomaly_detection.py)
#
# **Anomaly detection** (also **outlier detection**) is the identification of rare items, events or observations which raise suspicions by differing significantly from the majority of the data.
#
# The **normal** (or **Gaussian**) distribution is a very common continuous probability distribution. Normal distributions are important in statistics and are often used in the natural and social sciences to represent real-valued random variables whose distributions are not known. A random variable with a Gaussian distribution is said to be normally distributed and is called a normal deviate.
#
# > **Demo Project:** In this demo we will build a model that will find anomalies in server operational parameters such as `Latency` and `Throughput`.

# %%
# !pip install riskfolio-lib
# Out:
# Collecting riskfolio-lib
#   Downloading Riskfolio_Lib-2.0.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 5.7 MB/s  eta 0:00:01
# Collecting xlsxwriter>=1.3.7
#   Downloading XlsxWriter-3.0.2-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 48.3 MB/s eta 0:00:01
# Collecting arch>=4.15
#   Downloading arch-5.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (902 kB)
#      |████████████████████████████████| 902 kB 50.5 MB/s eta 0:00:01
# Collecting networkx>=2.5.1
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 40.7 MB/s eta 0:00:01
# Collecting astropy>=4.3.1
#   Downloading astropy-4.3.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 52.7 MB/s eta 0:00:01         | 2.8 MB 52.7 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from riskfolio-lib) (1.1.0)
# Collecting matplotlib>=3.3.0
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 34.1 MB/s eta 0:00:01
# Collecting scikit-learn>=0.22.0
#   Downloading scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 37.1 MB/s eta 0:00:01
# Collecting pandas>=1.0.0
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 48.1 MB/s eta 0:00:01
# Collecting statsmodels>=0.10.1
#   Downloading statsmodels-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 30.4 MB/s eta 0:00:01
# Collecting cvxpy>=1.0.25
#   Downloading cvxpy-1.1.18-cp37-cp37m-manylinux_2_24_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 36.8 MB/s eta 0:00:01
# Collecting numpy>=1.17.0
#   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 17.1 MB/s eta 0:00:01�█████▋                  | 6.7 MB 17.1 MB/s eta 0:00:01
# Collecting scipy>=1.0.1
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 47 kB/s s eta 0:00:01
# Collecting property-cached>=1.6.4
#   Downloading property_cached-1.6.4-py2.py3-none-any.whl (7.8 kB)
# Collecting pyerfa>=1.7.3
#   Downloading pyerfa-2.0.0.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (746 kB)
#      |████████████████████████████████| 746 kB 27.1 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.7/site-packages (from astropy>=4.3.1->riskfolio-lib) (4.6.3)
# Collecting osqp>=0.4.1
#   Downloading osqp-0.6.2.post5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (295 kB)
#      |████████████████████████████████| 295 kB 50.2 MB/s eta 0:00:01
# Collecting scs>=1.1.6
#   Downloading scs-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 46.7 MB/s eta 0:00:01
# Collecting ecos>=2
#   Downloading ecos-2.0.10-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (190 kB)
#      |████████████████████████████████| 190 kB 51.8 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3.0->riskfolio-lib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3.0->riskfolio-lib) (0.10.0)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 48.0 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3.0->riskfolio-lib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3.0->riskfolio-lib) (1.3.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.29.0-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 51.2 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.3.0->riskfolio-lib) (21.0)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cycler>=0.10->matplotlib>=3.3.0->riskfolio-lib) (1.16.0)
# Collecting qdldl
#   Downloading qdldl-0.1.5.post0-cp37-cp37m-manylinux2014_x86_64.whl (941 kB)
#      |████████████████████████████████| 941 kB 28.4 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.0.0->riskfolio-lib) (2021.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.0.0-py3-none-any.whl (14 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 41.1 MB/s eta 0:00:01
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 49.3 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.6.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata->astropy>=4.3.1->riskfolio-lib) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata->astropy>=4.3.1->riskfolio-lib) (3.5.0)
# Installing collected packages: numpy, scipy, qdldl, patsy, pandas, threadpoolctl, statsmodels, scs, pyerfa, property-cached, pillow, osqp, joblib, fonttools, ecos, xlsxwriter, scikit-learn, networkx, matplotlib, cvxpy, astropy, arch, riskfolio-lib
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.15.3
#     Uninstalling numpy-1.15.3:
#       Successfully uninstalled numpy-1.15.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.1.0
#     Uninstalling scipy-1.1.0:
#       Successfully uninstalled scipy-1.1.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 0.23.4
#     Uninstalling pandas-0.23.4:
#       Successfully uninstalled pandas-0.23.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.0.1
#     Uninstalling matplotlib-3.0.1:
#       Successfully uninstalled matplotlib-3.0.1
# Successfully installed arch-5.1.0 astropy-4.3.1 cvxpy-1.1.18 ecos-2.0.10 fonttools-4.29.0 joblib-1.1.0 matplotlib-3.5.1 networkx-2.6.3 numpy-1.21.5 osqp-0.6.2.post5 pandas-1.3.5 patsy-0.5.2 pillow-9.0.0 property-cached-1.6.4 pyerfa-2.0.0.1 qdldl-0.1.5.post0 riskfolio-lib-2.0.0 scikit-learn-1.0.2 scipy-1.7.3 scs-3.1.0 statsmodels-0.13.1 threadpoolctl-3.0.0 xlsxwriter-3.0.2
